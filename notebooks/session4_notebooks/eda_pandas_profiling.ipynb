# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(r"C:\capstone_project_dscience\real_estate_project\dataset\cleaned_gurgaon_v2.csv").drop_duplicates()

# %%
profile = ProfileReport(df, title="Gurgaon Real Estate Data Profiling Report", explorative=True)
profile.to_file("gurgaon_real_estate_data_profiling_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
